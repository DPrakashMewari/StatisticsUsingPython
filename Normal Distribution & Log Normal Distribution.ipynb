# %% [raw]
# Normal Distribution : It is Bell shaped Curve
#
# In center there is mean 0 and std 1
#
# It fits the many events through by Probablity Distribution Ex:
# Height,Weight,Prices
#
#
# Emperical Rule : 1 std 68%
#                  2 std 95%
#                  3 std 99.7%

# %%
import numpy 
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import random

x = random.normal(size=1000)
sns.distplot(x)
plt.show()
# It convert 1000 into pdf

# %% [raw]
# PDF: Probability Density Function, returns the probability of a given continuous outcome.
# CDF: Cumulative Distribution Function, returns the probability of a value less than or equal to a given outcome.
# PPF: Percent-Point Function, returns a discrete value that is less than or equal to the given probability.

# %%
# Log Normal Distribution :

from scipy.stats import lognorm 
import matplotlib.pyplot as plt 

fig,ax = plt.subplots(1,1)
s = 0.800
# Declare few moments - moments are like first order,second order... 
mean,var,skew,kurt = lognorm.stats(s,moments="mvsk")

x = np.linspace(lognorm.ppf(0.01,s),lognorm.ppf(0.99,s),100)
ax.plot(x,lognorm.pdf(x,s))

# %% [raw]
#  We can also convert log normal Distribution, into standard normal Distribution !
